# %% [markdown]
# ## File Handling and Operations
# ### Assignment 1: Reading a File
#
# Write a function that reads the contents of a file named `sample.txt` and prints each line.

# %%
def read_file():
    with open('sample.txt','w') as f:
        f.write('Hello Ganesh. Word very hard to become Data scientist.')
        for line in f:
            print(line.strip)

read_file()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[3], line 7
#       4         for line in f:
#       5             print(line.strip)
# ----> 7 read_file()
#
# Cell In[3], line 4, in read_file()
#       2 with open('sample.txt','w') as f:
#       3     f.write('Hello Ganesh. Word very hard to become Data scientist.')
# ----> 4     for line in f:
#       5         print(line.strip)
#
# UnsupportedOperation: not readable
