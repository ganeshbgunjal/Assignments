# %% [markdown]
# ### Python Basics Assignment:--

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
name = input('Enter your name: ')
age = int(input('Enter age:'))
print(f'Name is: {name}')
print(f'Age is: {age}')
# Out:
# Enter your name:  ganesh
# Enter age: 33
# Name is: ganesh
# Age is: 33

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
number = int(input('Enter num:'))
if number < 0:
    print('Number is negative')
elif number > 0:
    print('Number is positive')
else:
    print('Number is zero')
# Out:
# Enter num: -1
# Number is negative

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
num1 = int(input('Enter number1:'))
num2 = int(input('Enter number2:'))
num3 = int(input('Enter number3:'))

if num1>num2 and num1>num3:
    print(f'{num1} is greater')
elif num2>num1 and num2>num3:
    print(f'{num2} 2 is greater')
else:
    print(f'{num3} is greater')
# Out:
# Enter number1: 15
# Enter number2: 13
# Enter number3: 2
# 15 is greater

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %% [markdown]
# ### using for loop

# %%
num = int(input('enter num:'))

factorial = 1

for i in range(1, num+1):
    factorial *= i

print(f'Factorial of {num} is {factorial}')
# Out:
# enter num: 5
# Factorial of 5 is 120

# %% [markdown]
# ### using recursion:

# %%
def factorial(n):
    if n==0 or n==1:
        return  1
    else:
        return n *factorial(n-1)

num = int(input('Enter num:'))
print(f'factorial of {num} is {factorial(num)}')
# Out:
# Enter num: 5
# factorial of 5 is 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
name = 'Ganesh'
age = 33
marks = 59.66
is_umarried = True

# --------------------
print(name)
print(type(name))
# --------------------
print(age)
print(type(age))
# --------------------
print(marks)
print(type(marks))
# --------------------
print(is_umarried)
print(type(is_umarried))
# --------------------
# Out:
# Ganesh
# <class 'str'>
# 33
# <class 'int'>
# 59.66
# <class 'float'>
# True
# <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
val1 = 11
val2 = 22

print(f'Before swapping: val1: {val1} and val2: {val2}')

val1,val2 = val2,val1

print(f'After swapping: val1: {val1} and val2: {val2}')
# Out:
# Before swapping: val1: 11 and val2: 22
# After swapping: val1: 22 and val2: 11

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
celcius = float(input('Enter temp in celcius:'))
fahreinheit = (celcius * 9/5)+32

print(f'{celcius} C is equal to {fahreinheit} F')
# Out:
# Enter temp in celcius: 37
# 37.0 C is equal to 98.6 F
