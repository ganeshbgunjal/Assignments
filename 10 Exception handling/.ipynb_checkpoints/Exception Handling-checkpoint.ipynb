# %% [markdown]
# # Exception Handling Assignments
# ## Exception Handling with try, except, and finally

# %% [markdown]
# ### Assignment 1: Handling Division by Zero
#
# Write a function that takes two integers as input and returns their division. Use try, except, and finally blocks to handle division by zero and print an appropriate message.

# %%
def division(a,b):
    try:
        result = a/b
    except ZeroDivisionError as e:
        print(f'Error: {e}')
        result = None
    finally:
        print('Excution completed.')
        return result

print(division(4,2))
print('---------------------------------------------')
print(division(10,0))
# Out:
# Excution completed.
# 2.0
# ---------------------------------------------
# Error: division by zero
# Excution completed.
# None

# %% [markdown]
# ### Assignment 2: File Reading with Exception Handling
#
# Write a function that reads the contents of a file named `data.txt`. Use try, except, and finally blocks to handle file not found errors and ensure the file is properly closed.

# %%
def read_file(filename):
    try: 
        file = open(filename,'r')
        data = file.read()
        return data
    except FileNotFoundError as e:
        print(f'Error: {e}')
    finally:
        try:
            file.close()
        except NameError:
            pass

print(read_file('sample.txt'))
print('---------------------------------')
print(read_file('abc.txt'))
# Out:
# Hello Ganesh.
# Work hard for your dream.
# Be a good Data Scientist.
# ---------------------------------
# Error: [Errno 2] No such file or directory: 'abc.txt'
# None

# %% [markdown]
# ### Assignment 3: Handling Multiple Exceptions
#
# Write a function that takes a list of integers and returns their sum. Use try, except, and finally blocks to handle TypeError if a non-integer value is encountered and print an appropriate message.

# %%
def list_sum(lst):
    total = 0
    try:
        for item in lst:
            total = total+item
    except Exception as e:
        print(f'Error: {e}')
    finally:
        print(f'Code executed.')
        return total
        


print(f'Test 1: {list_sum([1,2,3,4,5])}')
print(f'Test 2: {list_sum([3,5,7,8,9])}')
print(f'Test 3: {list_sum([1,2,3,'a'])}')
# Out:
# Code executed.
# Test 1: 15
# Code executed.
# Test 2: 32
# Error: unsupported operand type(s) for +: 'int' and 'str'
# Code executed.
# Test 3: 6

# %% [markdown]
# ### Assignment 4: Exception Handling in User Input
#
# Write a function that prompts the user to enter an integer. Use try, except, and finally blocks to handle ValueError if the user enters a non-integer value and print an appropriate message.

# %%
def get_integer():
    try:
        val = int(input('Enter number:'))
        print(val)
    except Exception as e:
        print(f'Error: {e}')
    finally:
        print(f'code executed!')

print(f'Test 1: {get_integer()}')
print(f'Test 2: {get_integer()}')
# Out:
# Enter number: 1
# 1
# code executed!
# Test 1: None
# Enter number: a
# Error: invalid literal for int() with base 10: 'a'
# code executed!
# Test 2: None

# %% [markdown]
# ### Assignment 5: Exception Handling in Dictionary Access
#
# Write a function that takes a dictionary and a key as input and returns the value associated with the key. Use try, except, and finally blocks to handle KeyError if the key is not found in the dictionary and print an appropriate message.

# %%
def get_dict_key(d,key):
    try:
        val = d[key]
    except Exception as e:
        print(f'Error: {e}')
        val = None
    finally:
        print('Code executed')
    return val

d={'a':1,'b':2,'c':3}

print(get_dict_key(d,'b'))
print(get_dict_key(d,'e'))
# Out:
# Code executed
# 2
# Error: 'e'
# Code executed
# None

# %% [markdown]
# ### Assignment 6: Nested Exception Handling
#
# Write a function that performs nested exception handling. It should first attempt to convert a string to an integer, and then attempt to divide by that integer. Use nested try, except, and finally blocks to handle ValueError and ZeroDivisionError and print appropriate messages.

# %%
def neststed_exception_handling(s):
    try:
        try:
            num = int(s)
        except Exception as e:
            print(f'Error: {e}')
            num = None
        finally:
            print('Conversion complete')
        if num is not None:
            try:
                result = 10/num
            except Exception as e:
                print(f'Error: {e}')
                result = None
            finally:
                print(f'Division attempt completed')
                return result
    finally:
        print(f'Overall execution completed')

print(f'Test 1: {neststed_exception_handling('0')}')
print(f'Test 2: {neststed_exception_handling('2')}')
print(f'Test 3: {neststed_exception_handling('a')}')
# Out:
# Conversion complete
# Error: division by zero
# Division attempt completed
# Overall execution completed
# Test 1: None
# Conversion complete
# Division attempt completed
# Overall execution completed
# Test 2: 5.0
# Error: invalid literal for int() with base 10: 'a'
# Conversion complete
# Overall execution completed
# Test 3: None

# %% [markdown]
# ### Assignment 7: Exception Handling in List Operations
#
# Write a function that takes a list and an index as input and returns the element at the given index. Use try, except, and finally blocks to handle IndexError if the index is out of range and print an appropriate message.

# %%
def get_list_element(lst,index):
    try:
        element = lst[index]
    except Exception as e:
        print(f'Error: {e}')
        element = None
    finally:
        print('Execution completed.')
        return element

lst=[1,2,3,4,5,6]
str_lst = ['a','d','v','g','t']

try:
    index = int(input('Enter number: '))
    print(f'element at {index} is: {get_list_element(lst,index)}')
    print(f'character at {index} is: {get_list_element(str_lst,index)}')

except Exception as e:
    print(f'Error: {e}')
# Out:
# Enter number:  5
# Execution completed.
# element at 5 is: 6
# Error: list index out of range
# Execution completed.
# character at 5 is: None

# %% [markdown]
# ### Assignment 8: Exception Handling in Network Operations
#
# Write a function that attempts to open a URL and read its contents. Use try, except, and finally blocks to handle network-related errors and print an appropriate message.

# %%
import requests

def read_url(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.text
    except requests.RequestException as e:
        print(f'Network error: {e}')
        return None
    finally:
        print('Excution completed.')

print(read_url('https://jsonplaceholder.typicode.com/posts/1'))
print(read_url('https://nonexistent.url'))
# Out:
# Excution completed.
# {
#   "userId": 1,
#   "id": 1,
#   "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#   "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
# }
# Network error: HTTPSConnectionPool(host='nonexistent.url', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000130D0BE75F0>: Failed to resolve 'nonexistent.url' ([Errno 11001] getaddrinfo failed)"))
# Excution completed.
# None

# %% [markdown]
# ### Assignment 9: Exception Handling in JSON Parsing
#
# Write a function that attempts to parse a JSON string. Use try, except, and finally blocks to handle JSONDecodeError if the string is not a valid JSON and print an appropriate message.

# %% [markdown]
# json load() and loads()
# load() used for reding data from file opened in text or binary mode.
# loads() used for reading data from  string. data from API

# %%
import json

def parse_json(json_string):
    try:
        data = json.loads(json_string)
        return data
    except Exception as e:
        print(f'Json error: {e}')
        return None
    finally:
        print('Execution completed.')


print(f'Test 1: {parse_json('{"name": "John", "age": 30}')}')  
print(f'Test 2: {parse_json('Invalid JSON')}')
# Out:
# Execution completed.
# Test 1: {'name': 'John', 'age': 30}
# Json error: Expecting value: line 1 column 1 (char 0)
# Execution completed.
# Test 2: None

# %% [markdown]
# ### Assignment 10: Custom Exception Handling
#
# Define a custom exception named `NegativeNumberError`. Write a function that raises this exception if a negative number is encountered in a list. Use try, except, and finally blocks to handle the custom exception and print an appropriate message.

# %%
class NegativeNumberError(Exception):
    pass
def check_for_negatives(lst):
    try:
        for num in lst:
            if num < 0:
                raise NegativeNumberError(f'Negative number found. {num}')
        return lst
           
    except NegativeNumberError as e:
        print(f'Error: {e}')
        return None
    finally:
        print(f'excution completed')
        

print(f'Test 1: {check_for_negatives([1,2,-3,4])}')
print(f'Test 2: {check_for_negatives([1,2,3,4])}')
# Out:
# Error: Negative number found. -3
# excution completed
# Test 1: None
# excution completed
# Test 2: [1, 2, 3, 4]
