# %% [markdown]
# ## Polymorphism, Abstraction, and Encapsulation

# %% [markdown]
# ### Assignment 1: Polymorphism with Methods
#
# Create a base class named `Shape` with a method `area`. Create two derived classes `Circle` and `Square` that override the `area` method. Create a list of `Shape` objects and call the `area` method on each object to demonstrate polymorphism.

# %%
import math

class Shape:
    def area(self):
        pass

class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius

    def area(self):
        return f'Circle Area: {math.pi * self.radius**2}'

class Square(Shape):
    def __init__(self,side):
        self.side = side

    def area(self):
        return f'Square area: {self.side * self.side}'

shapes = [Circle(5),Square(6)]
for shape in shapes:
    print(shape.area())
# Out:
# Circle Area: 78.53981633974483
# Square area: 36

# %% [markdown]
# ### Another approach:

# %%
circle = Circle(5)
print(circle.area())

square = Square(6)
print(square.area())
# Out:
# Circle Area: 78.53981633974483
# Square area: 36

# %% [markdown]
# ### Assignment 2: Polymorphism with Function Arguments
#
# Create a function named `describe_shape` that takes a `Shape` object as an argument and calls its `area` method. Create objects of `Circle` and `Square` classes and pass them to the `describe_shape` function.

# %%
def describe_shape(shape):
    return f'Area of describe shape is: {shape.area()}'


circle = Circle(5)
square = Square(6)
print(describe_shape(circle))
print(describe_shape(square))
# Out:
# Area of describe shape is: Circle Area: 78.53981633974483
# Area of describe shape is: Square area: 36
